# %%
import pickle
import pandas as pd

# Data Collection
dataset=pd.read_csv("insurance_pre.csv")

#Data preprocessing - categorical value to numerical value - using One Hot Encoding method
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']] # features/input 
dep=dataset[['charges']] # target/output

# %%
# split train and test set
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(indep,dep,test_size=0.3, random_state=0)

# %%
# Standardisation
# Pre processing - rescales data to a consistent format - easier to understand and use

from sklearn.preprocessing import StandardScaler
scx=StandardScaler() # pre-processed input
X_train=scx.fit_transform(X_train)
X_test=scx.transform(X_test)
X_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
scy=StandardScaler() # pre-processed output
Y_train=scy.fit_transform(Y_train)
Y_test=scy.transform(Y_test)
Y_test
# Out:
# array([[-2.95473865e-01],
#        [-3.94586401e-01],
#        [ 2.73452549e+00],
#        [-2.38210314e-02],
#        [-3.02234780e-01],
#        [-7.35451572e-01],
#        [-9.29336992e-01],
#        [-1.51272887e-01],
#        [-4.79692315e-01],
#        [-6.57575321e-01],
#        [-5.45730852e-01],
#        [-2.30674202e-01],
#        [-4.96486983e-01],
#        [-7.62000979e-01],
#        [ 4.27650930e-01],
#        [-2.13097920e-01],
#        [-5.97377347e-02],
#        [-8.20495396e-01],
#        [-5.70591936e-01],
#        [ 1.70484300e+00],
#        [ 9.04049301e-01],
#        [-4.96505360e-02],
#        [ 8.26414524e-01],
#        [ 8.28086660e-01],
#        [-9.73430644e-01],
#        [-7.21364344e-01],
#        [-8.00107923e-01],
#        [-4.67437893e-01],
#        [-7.98086955e-01],
#        [-4.05891011e-01],
#        [-4.35686449e-01],
#        [ 3.00977314e+00],
#        [-2.13545175e-02],
#        [ 6.23001101e-01],
#        [ 1.12767486e-01],
# ...

# %%
# Loading the saved model
filename="final_model.sav"
model=pickle.load(open(filename,'rb'))
model
# Out:
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100]},
#              verbose=5)

# %%
# Userr
age=int(input("Age:"))
bmi=float(input("BMI:"))
children=int(input("Children:"))
sex_male=int(input("Sex_Male: 0/1"))
smoker_yes=int(input("Smoker_yes 0 / 1: "))
# Out:
# Age: 25
# BMI: 25
# Children: 4
# Sex_Male: 0/1 1
# Smoker_yes 0 / 1:  1

# %%
# Transform the user input data using the input scaler
preInput=scx.transform([[age,bmi,children,sex_male,smoker_yes]])
preInput
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.03327874, -0.92299913,  2.42515947,  1.02378711,  1.98149332]])

# %%
# Predict the standardized output using the trained model
result=model.predict(preInput)
result
# Out:
# array([0.37945301])

# %%
# Inverse transform the output to get the raw output/ future prediction
preOutput=scy.inverse_transform([result])
print(f"Futue Prediction: {preOutput[0][0]:.2f}")
# Out:
# Futue Prediction: 17738.45
